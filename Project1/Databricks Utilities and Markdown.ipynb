# %% [markdown]
# Databricks Utilites
#
# File system Utility
# Secrets Utility
# Widget Utility
# Noebook Workflow Uitlity

# %%
# %fs
ls /databricks-datasets/weather/high_temps

# %%
display(dbutils.fs.ls("/databricks-datasets/"))

# %%
items = dbutils.fs.ls("/databricks-datasets/")
len(items)

# %%
[item for item in items if not item.name.endswith("/")]

# %%
dbutils.help()
dbutils.fs.help()
# dbutils.fs.help("cp")

# %%
# %fs
head /databricks-datasets/weather/high_temps

# %%
# %sh
ps

# %%
# %pip list

# %%
# %pip install faker

# %%
# %restart_python

# %%
dbutils.library.restartPython()

# %% [markdown]
# ### %run : Include / import another notebook into current notebook

# %%
# %run "/Workspace/Repos/ajesh7s@gmail.com/databricks/Project1/Functions"

# %%
print_env_info()
env

# %%
df=(spark.read
        .format("csv")
        .option("header","true")
        .option("inferSchema","true")
        .load("/databricks-datasets/weather/high_temps"))

display(df);

# %% [markdown]
# # This is heading
# ## Heading 2
# _Italic words_
#
# `code`
#
#
# ```
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "age": 25
# }
#
# ```
#
# [link](google.com)
#
# ![image](https://www.google.com/imgres?q=google%20images%20databricks&imgurl=https%3A%2F%2Fcoefficient.io%2Fwp-content%2Fuploads%2F2024%2F08%2Fdatabricks-gallery-logo.png&imgrefurl=https%3A%2F%2Fcoefficient.io%2Fintegrations-google-sheets%2Fdatabricks&docid=hhGstpBZeQfC-M&tbnid=XjxolSWLVkVEZM&vet=12ahUKEwidnov_1ZuRAxWPUfUHHWYDISwQM3oECH4QAA..i&w=800&h=800&hcb=2&ved=2ahUKEwidnov_1ZuRAxWPUfUHHWYDISwQM3oECH4QAA)
#
#
# - point 1
# - point 2
#
#
# > in quotes
#
# ~~The world is flat.~~
#
#
# term
# : definition
#
#
#
# Here's a sentence with a footnote. [^1]
#
# [^1]: This is the footnote.
#
#
#
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
#
#
# I need to highlight these ==very important words==
